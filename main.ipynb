# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
daily_input_costs = pd.read_csv('daily_input_costs.csv')

# %%
daily_input_costs.head()
# Out:
#          date plot_id greenhouse_id farm_id  daily_energy_cost  \
# 0  2025-02-15   P0001         GH003     F08           0.000000
# 1  2025-02-16   P0001         GH003     F08           7.415873
# 2  2025-02-17   P0001         GH003     F08           0.000000
# 3  2025-02-18   P0001         GH003     F08           0.000000
# 4  2025-02-19   P0001         GH003     F08           0.000000
#
#    daily_fertilizer_cost  daily_labor_cost  daily_pesticide_cost  \
# 0                    0.0          0.000000                   0.0
# 1                    0.0         30.052106                   0.0
# 2                    0.0          0.000000                   0.0
# 3                    0.0          0.000000                   0.0
# 4                    0.0          0.000000                   0.0
#
#    daily_water_cost  daily_total_input_cost  daily_precision_cost  \
# 0          0.000000                0.000000                   0.0
# ...
